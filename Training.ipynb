# %% [markdown]
# ## Colab Stuff
#
# It's highly recommended to download the dataset first to your drive and work on Google Colab to save your time (and your local machine too:)))

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# %cd '/content/gdrive/My Drive'

# %% [markdown]
# ## Datasets
#
# The official website of `PASCAL VOC` dataset is not working. So, you will need to search for a new way:
# 1. This is an alternative website which we used: [https://deepai.org/dataset/pascal-voc](https://deepai.org/dataset/pascal-voc)
# 2. Use our shared version from [Google Drive](https://drive.google.com/drive/folders/1wyB3XcD8EhiZI1BZYZ5SawG-DOwZzBV_?usp=sharing) in case the alternative website isn't available too.
#
# P.S. Our drive folder contains only `PASCAL VOC 2007`. If you need a compressed folder for `PASCAL VOC 2012`, you can easily find it [here](https://drive.google.com/file/d/1XU7qwUVnV2S_iiWfb4DEmoxjbnQJxpHE/view?usp=sharing://) on our Google Drive too :)

# %% [markdown]
# ## Reading Dataset

# %%
from utils.agent import *
from utils.dataset import read_voc_dataset
from IPython.display import clear_output
import tqdm.notebook as tq
# %reload_ext autoreload
# %autoreload 2

train_loader2007, _ = read_voc_dataset(path="/kaggle/input/pascal-voc-2007/VOCtrainval_06-Nov-2007" ,year='2007')

# %% [markdown]
# ## Dataset Organization

# %%
#put datalist in list in case of combination of different datasets
#For example: [train_loader2007, train_loader2012]
datasets_per_class = sort_class_extract([train_loader2007])
# Out:
#   0%|          | 0/2501 [00:00<?, ?it/s]

# %% [markdown]
# ## Training Loop

# %%
for i in range(len(classes)):
    classe = classes[i]
    print("Classe "+str(classe)+"...")
    agent = Agent(classe, alpha=0.2, num_episodes=5, load=False, model_name='vgg16')
    agent.train(datasets_per_class[classe])
    del agent
    torch.cuda.empty_cache()
# Out:
# Classe cat...
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# Episode 0
#   0%|          | 0/166 [00:00<?, ?it/s]
# /kaggle/working/Active-Object-Localization/utils/agent.py:176: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   non_final_next_states = Variable(torch.cat(next_states), volatile=True).type(Tensor)
# /kaggle/working/Active-Object-Localization/utils/agent.py:194: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   next_state_values.volatile = False
# Saved
# Complete
# Episode 1
#   0%|          | 0/166 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 2
#   0%|          | 0/166 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 3
#   0%|          | 0/166 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 4
#   0%|          | 0/166 [00:00<?, ?it/s]
# Saved
# Complete
# Classe cow...
# Episode 0
#   0%|          | 0/71 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 1
#   0%|          | 0/71 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 2
#   0%|          | 0/71 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 3
#   0%|          | 0/71 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 4
#   0%|          | 0/71 [00:00<?, ?it/s]
# Saved
# Complete
# Classe dog...
# Episode 0
#   0%|          | 0/210 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 1
#   0%|          | 0/210 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 2
#   0%|          | 0/210 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 3
#   0%|          | 0/210 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 4
#   0%|          | 0/210 [00:00<?, ?it/s]
# Saved
# Complete
# Classe bird...
# Episode 0
#   0%|          | 0/182 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 1
#   0%|          | 0/182 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 2
#   0%|          | 0/182 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 3
#   0%|          | 0/182 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 4
#   0%|          | 0/182 [00:00<?, ?it/s]
# Saved
# Complete
# Classe car...
# Episode 0
#   0%|          | 0/402 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 1
#   0%|          | 0/402 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 2
#   0%|          | 0/402 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 3
#   0%|          | 0/402 [00:00<?, ?it/s]
# Saved
# Complete
# Episode 4
#   0%|          | 0/402 [00:00<?, ?it/s]
# Saved
# Complete
